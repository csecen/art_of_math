# %%
import math
import matplotlib.pyplot as plt
import numpy as np

# %%
# 100 linearly spaced numbers
x = np.linspace(-20,20,100)

# the function, which is y = x^2 here
y = abs((6*x)+1)

fig, ax = plt.subplots()
fig.set_size_inches(20, 10)
fig.patch.set_visible(True)
fig.patch.set_facecolor('white')
ax.axis('off')


# plot the function
plt.plot(x,y, 'r')
x = np.linspace(-20,200000, 200000)
tps = \
[((3,5),'g'), ((5,7), 'b'), ((11,13), 'purple'), ((17,19), 'pink'), ((29,31), 'orange'), 
 ((41,43), 'g'), ((59,61), 'b'), ((71,73), 'purple'), ((101, 103), 'pink'), ((107, 109), 'orange'), 
 ((137, 139), 'g'), ((149, 151), 'b'), ((179, 181), 'purple'), ((191, 193), 'pink'), ((197, 199), 'orange'),
 ((227, 229), 'g'), ((239, 241), 'b'), ((269, 271), 'purple'), ((281, 283), 'pink'), ((311, 313), 'orange'),
 ((347, 349), 'g'), ((419, 421), 'b'), ((431, 433), 'purple'), ((461, 463), 'pink'), ((521, 523), 'orange'),
 ((569, 571), 'g'), ((599, 601), 'b'), ((617, 619), 'purple'), ((641, 643), 'pink'), ((659, 661), 'orange'),
 ((809, 811), 'g'), ((821, 823), 'b'), ((827, 829), 'purple'), ((857, 859), 'pink'), ((881, 883), 'orange'), 
 ((1019, 1021), 'g')]

for t, c in tps:
    m = (t[0]+1)/6
    y = (x/m)+(6*m)
    plt.plot(x,y, c)
    
# show the plot
plt.xlim([-5, 200000])
plt.ylim([0, 3000])
plt.savefig('images/white_background.png')
plt.show()
